# %% [markdown]
# # Best shortcuts
# - shift + tab
# - %timeit command
#     - may not let the line save variables

# %%
import pandas as pd

# %%
series = pd.Series(['BMW', "Toyota", "Honda"])

# %%
series
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %%
colours = pd.Series(["red", "blue", "white"])
colours
# Out:
# 0      red
# 1     blue
# 2    white
# dtype: object

# %%
df = pd.DataFrame({"Car make" : series, "Colour": colours})
df
# Out:
#   Car make Colour
# 0      BMW    red
# 1   Toyota   blue
# 2    Honda  white

# %%
df = pd.read_csv("car-sales.csv")
df.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %% [markdown]
# # NUMPY

# %%
import numpy as np

# %%
a1 = np.array([1,2,3])
a1
# Out:
# array([1, 2, 3])

# %%
type(a1)
# Out:
# numpy.ndarray

# %%
ones = np.ones((2,3))

# %%
ones
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.]])

# %%
np.arange(0, 10, 2)
# Out:
# array([0, 2, 4, 6, 8])
